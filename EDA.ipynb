# %% [markdown]
# ### [DataSet Link](https://www.kaggle.com/code/rounakbanik/movie-recommender-systems/input)

# %%
# importing the 
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
movies = pd.read_csv(r'C:\Users\Aman\Downloads\Innomatics\Datasets\movies_metadata.csv')

# %%
movies.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
credits = pd.read_csv(r'C:\Users\Aman\Downloads\Innomatics\Datasets\credits.csv', error_bad_lines=False, engine="python")

# %%
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
#  1   crew    45476 non-null  object
#  2   id      45476 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %%
keywords = pd.read_csv(r'C:\Users\Aman\Downloads\Innomatics\Datasets\keywords.csv')

# %%
keywords.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
ratings = pd.read_csv(r'C:/Users/Aman/Downloads/Innomatics/Datasets/ratings_small.csv')

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
links = pd.read_csv('C:/Users/Aman/Downloads/Innomatics/Datasets/links_small.csv')

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
import ast

# %%
def convert(text, key='name', limit=3):
    L = []
    counter = 0
    for item in ast.literal_eval(text):
        if counter < limit:
            L.append(item.get(key))
            counter += 1
    return L

# %%
credits['cast'] = credits['cast'].apply(convert)

# %%
def fetch_director(text):
    L = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

# %%
credits['crew'] = credits['crew'].apply(fetch_director)

# %%
credits.head()
# Out:
#                                                 cast               crew     id
# 0                [Tom Hanks, Tim Allen, Don Rickles]    [John Lasseter]    862
# 1     [Robin Williams, Jonathan Hyde, Kirsten Dunst]     [Joe Johnston]   8844
# 2         [Walter Matthau, Jack Lemmon, Ann-Margret]    [Howard Deutch]  15602
# 3  [Whitney Houston, Angela Bassett, Loretta Devine]  [Forest Whitaker]  31357
# 4         [Steve Martin, Diane Keaton, Martin Short]    [Charles Shyer]  11862

# %%
keywords['keywords'] = keywords['keywords'].apply(convert)
keywords.head()
# Out:
#       id                                           keywords
# 0    862                               [jealousy, toy, boy]
# 1   8844  [board game, disappearance, based on children'...
# 2  15602       [fishing, best friend, duringcreditsstinger]
# 3  31357  [based on novel, interracial relationship, sin...
# 4  11862                 [baby, midlife crisis, confidence]

# %%
movies['genres'] = movies['genres'].apply(convert)

# %%
movies = movies.drop([19730, 29503, 35587])

# %%
keywords['id'] = keywords['id'].astype('int')
credits['id'] = credits['id'].astype('int')
movies['id'] = movies['id'].astype('int')

# %%
movies = movies.merge(credits,on='id')

# %%
movies = movies.merge(keywords,on = 'id')

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'cast', 'crew', 'keywords'],
#       dtype='object')

# %%
movies.shape
# Out:
# (46628, 27)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46628 entries, 0 to 46627
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  46628 non-null  object
#  1   belongs_to_collection  4574 non-null   object
#  2   budget                 46628 non-null  object
#  3   genres                 46628 non-null  object
#  4   homepage               8009 non-null   object
#  5   id                     46628 non-null  int32
#  6   imdb_id                46611 non-null  object
#  7   original_language      46617 non-null  object
#  8   original_title         46628 non-null  object
#  9   overview               45633 non-null  object
#  10  popularity             46624 non-null  object
#  11  poster_path            46229 non-null  object
#  12  production_companies   46624 non-null  object
#  13  production_countries   46624 non-null  object
# ...

# %%
movies.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    42054
# budget                       0
# genres                       0
# homepage                 38619
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   995
# popularity                   4
# poster_path                399
# production_companies         4
# production_countries         4
# release_date                88
# revenue                      4
# runtime                    268
# spoken_languages             4
# status                      86
# tagline                  25845
# title                        4
# video                        4
# vote_average                 4
# vote_count                   4
# cast                         0
# crew                         0
# keywords                     0
# dtype: int64

# %%
movies.cast = movies.cast.apply(lambda x: ''.join(x))

# %%
movies.crew = movies.crew.apply(lambda x: ''.join(x))
movies.keywords = movies.keywords.apply(lambda x: ''.join(x))

# %%
movies.genres = movies.genres.apply(lambda x: ''.join(x))

# %% [markdown]
# # Exploratory Data Analysis

# %%
movies['status'].value_counts()
# Out:
# Released           46164
# Rumored              240
# Post Production      100
# In Production         21
# Planned               15
# Canceled               2
# Name: status, dtype: int64

# %%
movies['status'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
movies['crew'].value_counts()
# Out:
#                                                        917
# John Ford                                               64
# Michael Curtiz                                          62
# Julien Duvivier                                         54
# Werner Herzog                                           53
#                                                       ...
# Joung Yumi                                               1
# Melville W. Brown                                        1
# Rob Cowan                                                1
# Yoshiharu AshinoVladimir ZhelezniakovAljosha Klimov      1
# Daisy Asquith                                            1
# Name: crew, Length: 18854, dtype: int64

# %%
movies['crew'].value_counts()[:10].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
movies['adult'].value_counts()
# Out:
# False    46619
# True         9
# Name: adult, dtype: int64

# %%
movies['original_language'].value_counts()
# Out:
# en    32937
# fr     2524
# it     1565
# ja     1420
# de     1111
#       ...
# jv        1
# qu        1
# la        1
# fy        1
# si        1
# Name: original_language, Length: 89, dtype: int64

# %%
movies['original_language'].value_counts()[:5].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
#converting title column to string
movies['title'] = movies['title'].astype('str')
movies['title'][0]
# Out:
# 'Toy Story'

# %%
from wordcloud import WordCloud
movie_title = ' '.join(movies['title'])
wordcloud = WordCloud(background_color='white').generate(movie_title)
plt.figure(figsize=(10,6))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
#Converting overview column to string
movies['overview'] = movies['overview'].astype('str')
movies['overview'][0]
# Out:
# "Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences."

# %%
overview_cr = ' '.join(movies['overview'])
wordcloud = WordCloud(background_color='white').generate(overview_cr)
plt.figure(figsize=(10,6))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
def clean(x):
    try:
        return float(x)
    except:
        return np.nan

# %%
movies['popularity'] = movies['popularity'].apply(clean).astype('float')
movies['vote_count'] = movies['vote_count'].apply(clean).astype('float')
movies['vote_average'] = movies['vote_average'].apply(clean).astype('float')

# %% [markdown]
# ### Most popular Movies

# %%
movies[['title', 'popularity']].sort_values('popularity', ascending=False).head(10)
# Out:
#                                 title  popularity
# 30910                         Minions  547.488298
# 33573                    Wonder Woman  294.337037
# 43388            Beauty and the Beast  287.253654
# 44809                     Baby Driver  228.032744
# 24657                      Big Hero 6  213.849907
# 26779                        Deadpool  187.860492
# 26781  Guardians of the Galaxy Vol. 2  185.330992
# 14723                          Avatar  185.070892
# 24553                       John Wick  183.870374
# 23870                       Gone Girl  154.801009

# %% [markdown]
# ### Least Popular Movies

# %%
movies[['title', 'popularity']].sort_values('popularity').head(10)
# Out:
#                                                    title  popularity
# 5691                                Night of the Zombies         0.0
# 15062                                      Lars i porten         0.0
# 38623                            Breaking with Old Ideas         0.0
# 20920                                  Business as Usual         0.0
# 20967                               The Castle of Cloads         0.0
# 38826  If These Knishes Could Talk: The Story of the ...         0.0
# 43379                                The Love of Ulysses         0.0
# 21204                               At the River I Stand         0.0
# 18762                                Pölynimurikauppiaat         0.0
# 18732                                   Casual Relations         0.0

# %% [markdown]
# ### Top Movies based on vote counts

# %%
movies[['title', 'vote_count']].sort_values('vote_count', ascending=False).head(10)
# Out:
#                          title  vote_count
# 15651                Inception     14075.0
# 12589          The Dark Knight     12269.0
# 14723                   Avatar     12114.0
# 18008             The Avengers     12000.0
# 26779                 Deadpool     11444.0
# 23076             Interstellar     11187.0
# 20254         Django Unchained     10297.0
# 23948  Guardians of the Galaxy     10014.0
# 2870                Fight Club      9678.0
# 18434         The Hunger Games      9634.0

# %% [markdown]
# ### Movies with least vote counts

# %%
movies[['title', 'vote_count']].sort_values('vote_count').head(10)
# Out:
#                                          title  vote_count
# 46627                                 Queerama         0.0
# 33795                            The Grim Game         0.0
# 33775                      Death of a Salesman         0.0
# 33746                                 Faustina         0.0
# 33740                             Love in Rome         0.0
# 33733                         Normal Young Man         0.0
# 33727                            Dirty Weekend         0.0
# 33723                           La notte brava         0.0
# 33716                              Meet Market         0.0
# 4363   All Access: Front Row. Backstage. Live!         0.0

# %% [markdown]
# ### Movies with low Runtime

# %%
movies[movies['runtime'] > 0][['runtime', 'title']].sort_values('runtime').head(10)
# Out:
#        runtime                                              title
# 41122      1.0                                Monkeyshines, No. 3
# 43047      1.0                   Gold Rush Scenes in the Klondike
# 45879      1.0                               The Infernal Caldron
# 43148      1.0  Batman Beyond Darwyn Cooke's Batman 75th Anniv...
# 45875      1.0                             The Roller Skate Craze
# 45869      1.0  Gymnasium Exercises and Drill at Newport Train...
# 27723      1.0                                        Santa Claus
# 45868      1.0                    Why Jones Discharged His Clerks
# 45867      1.0           Bird's-Eye View of Dock Front, Galveston
# 45865      1.0  Arrival of McKinley’s Funeral Train at Canton,...

# %% [markdown]
# ### Movies with high runtime

# %%
movies[movies['runtime'] > 0][['runtime', 'title']].sort_values('runtime', ascending = False).head(10)
# Out:
#        runtime                                title
# 24380   1256.0                           Centennial
# 20168   1140.0                                 Jazz
# 42104   1140.0                             Baseball
# 13918    931.0                Berlin Alexanderplatz
# 14111    925.0       Heimat: A Chronicle of Germany
# 28069    900.0        The Story of Film: An Odyssey
# 26896    877.0                                Taken
# 19348    874.0                              The War
# 34882    840.0  The Roosevelts: An Intimate History
# 34947    840.0          Seventeen Moments in Spring
